# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Assignment_1**

# %%
# 1. Create two 3×3 matrices with random integers in Python.
X=np.random.randint(0,10, size=(3,3))
Y=np.random.randint(0,10, size=(3,3))
print("Matrix1:\n",X)
print("Matrix1:\n",Y)


# 2.Perform addition, subtraction, and multiplication operations on these matrices.

matrix_sum = X + Y
matrix_diff = X- Y
matrix_prod = np.dot(X, Y)

print("ADDITION:\n",matrix_sum)
print("SUBTRACTION:\n",matrix_diff)
print("MULTIPLICATION:\n",matrix_prod)


# 3.Compute the determinant, inverse, and rank of one of the matrices.

det_Y = np.linalg.det(Y)


if np.linalg.det(Y) != 0:
    inv_Y = np.linalg.inv(Y)
else:
    inv_Y = "Matrix is singular, cannot compute inverse"

rank_Y = np.linalg.matrix_rank(Y)

print("Determinant of Y:", det_Y)
print("Inverse of Y:\n", inv_Y)
print("Rank of Y:", rank_Y)
# Out:
# Matrix1:
#  [[4 7 4]
#  [3 1 5]
#  [2 2 3]]
# Matrix1:
#  [[3 5 5]
#  [4 6 6]
#  [7 3 2]]
# ADDITION:
#  [[ 7 12  9]
#  [ 7  7 11]
#  [ 9  5  5]]
# SUBTRACTION:
#  [[ 1  2 -1]
#  [-1 -5 -1]
#  [-5 -1  1]]
# MULTIPLICATION:
#  [[68 74 70]
#  [48 36 31]
#  [35 31 28]]
# Determinant of Y: 1.9999999999999922
# Inverse of Y:
#  [[-3.00000000e+00  2.50000000e+00 -8.24737104e-16]
#  [ 1.70000000e+01 -1.45000000e+01  1.00000000e+00]
#  [-1.50000000e+01  1.30000000e+01 -1.00000000e+00]]
# Rank of Y: 3

# %% [markdown]
# **ASSIGNMENT_2**

# %%
# 1.Generate and Plot Two Random Vectors:
# a.Create two vectors, each containing 15 random floats.
vec1 = np.random.rand(15)
vec2 = np.random.rand(15)

print("for vector1:\n", vec1)
print("for vector2:\n", vec2)


# b.Plot these vectors on the same graph using matplotlib to compare how they look.
# C.Label the axes appropriately and give the plot a title.


# x = np.arange(len(vec1))

# Plot the data
plt.plot(x, vec1, marker='o', linestyle='-', label="Matrix X")
plt.plot(x, vec2, marker='s', linestyle='--', label="Matrix Y")
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Line Graph of Flattened Matrices X and Y")
plt.legend()
plt.grid(True)
plt.show()


# 2.Generate and Visualize a Random Matrix:

# Generate a 4x4 matrix with random values
matrix = np.random.rand(4, 4) #by default [0,1) which includes 0 but excludes 1
print(matrix)
# Plot the heatmap
sns.heatmap(matrix, annot=True, cmap='coolwarm', linewidths=0.5, linecolor ='black')
plt.title('Heatmap of 4x4 Matrix')
plt.show()

# Matrix Operations and Visualization:


# Create two random 4x4 matrices with integer values between 0 and 10

A = np.random.randint(0, 10, size=(4, 4))  # Random integers between 0 and 9
B = np.random.randint(0, 10, size=(4, 4))  # Random integers between 0 and 9

print("Matrix A:\n", A)
print("Matrix B:\n", B)

# Matrix operations
matrix_sum = A + B  # Matrix addition
matrix_diff = A - B  # Matrix subtraction
matrix_prod = np.dot(A, B)  # Matrix multiplication (dot product)

# Bar plot to visualize results
fig, axes = plt.subplots(1, 3, figsize=(15, 5)) #figure object, subplot array

# Sum
axes[0].bar(range(1, 17), matrix_sum.flatten(), color='b')
axes[0].set_title('Matrix Addition')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Value')

# Difference
axes[1].bar(range(1, 17), matrix_diff.flatten(), color='g')
axes[1].set_title('Matrix Subtraction')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Value')

# Product
axes[2].bar(range(1, 17), matrix_prod.flatten(), color='r')
axes[2].set_title('Matrix Multiplication')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Value')

plt.tight_layout() #plt.tight_layout() is a Matplotlib function that automatically adjusts the layout of subplots and figures to prevent overlapping and ensure a visually appealing presentation. It modifies the spacing between subplots, axes, labels, and titles to improve readability.
plt.show()
# Out:
# for vector1:
#  [0.36580849 0.28630325 0.78325563 0.59700368 0.50086473 0.82599349
#  0.25810703 0.51278861 0.65861171 0.08231913 0.49884816 0.84634277
#  0.63170884 0.28405206 0.57890011]
# for vector2:
#  [0.71599501 0.48131192 0.25083938 0.75553088 0.30255713 0.35360409
#  0.49360309 0.05469839 0.37315375 0.42548508 0.69737813 0.28279159
#  0.36773813 0.49674723 0.62313088]
# [[0.54589957 0.62407264 0.91274163 0.54152892]
#  [0.76938315 0.70450853 0.79428099 0.78183564]
#  [0.28718872 0.42280589 0.54325742 0.81208914]
#  [0.20284386 0.54447011 0.95114779 0.96551056]]
# Matrix A:
#  [[4 9 4 9]
#  [8 2 8 1]
#  [6 3 6 7]
#  [7 6 1 5]]
# Matrix B:
#  [[0 6 8 2]
#  [5 0 1 7]
#  [8 2 6 8]
#  [5 1 5 8]]
