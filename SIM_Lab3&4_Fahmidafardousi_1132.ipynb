# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Uniform Random Numbers:**

# %%
random_data = np.random.rand(10)
plt.hist(random_data, bins=5,  alpha=0.5, color='g', edgecolor='black')
# Out:
# (array([3., 1., 1., 2., 3.]),
#  array([0.14764824, 0.31099528, 0.47434233, 0.63768937, 0.80103642,
#         0.96438346]),
#  <BarContainer object of 5 artists>)

# %%
NormalValues = np.random.normal(0, 1, 500)
plt.hist(NormalValues, bins=10, alpha=0.9, edgecolor='b')
# Out:
# (array([  3.,   9.,  36.,  71., 103., 145.,  72.,  44.,  12.,   5.]),
#  array([-3.25025732, -2.62046399, -1.99067065, -1.36087731, -0.73108398,
#         -0.10129064,  0.5285027 ,  1.15829604,  1.78808937,  2.41788271,
#          3.04767605]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Student Lab Assignment

# %%
# With Seed
np.random.seed(10)  # Setting seed to 10
seeded_matrix = np.random.randint(1, 51, (3, 3))
print("Seeded Random Matrix:\n", seeded_matrix)

# Without Seed
np.random.seed(None)  # No seed, generates different values each time
non_seeded_matrix = np.random.randint(1, 51, (3, 3))
print("\nNon-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Seeded Random Matrix:
#  [[10 37 16]
#  [ 1 50 29]
#  [26 30 49]]
#
# Non-Seeded Random Matrix:
#  [[ 6 27 31]
#  [22 13  4]
#  [ 7 44 34]]

# %% [markdown]
# **Monte Carlo Simulation**

# %%
1.

import random
def estimate_pi(num_points):
    inside = 0
    for i in range(num_points):
        x = random.uniform(0,3)
        y = random.uniform(0,3)
        if x*x + y*y <= 9:
            inside += 1  # it's inside the circle

    pi = 4 * inside / num_points
    print("Estimated pi for", num_points, "points is:", pi)


estimate_pi(200*15)
# Out:
# Estimated pi for 3000 points is: 3.1746666666666665
